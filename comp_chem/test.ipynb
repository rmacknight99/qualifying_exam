# %%
import pandas as pd

pd.read_csv("summary_09_28_2022.csv", index_col=0)
# Out:
#                                         dimerization  monomer_complexation  \
# aluminum_bromide                               -15.1                 -17.4
# aluminum_chloride                              -18.5                 -19.1
# aluminum_nitrate                                 NaN                 -14.6
# aluminum_phosphate                               NaN                 -64.1
# aluminum_trifluoromethanesulfonate               NaN                   0.8
# boron_trifluoride                                NaN                   NaN
# copper_ii_chloride                              27.3                 -13.7
# copper_ii_flouride                              58.9                 -16.6
# copper_ii_sulfate                              -66.6                 -24.8
# copper_ii_trifluoromethanesulfonate             34.2                   1.0
# indium_iii_chloride                            -17.9                 -11.5
# ...
